# %%
from sqlalchemy import create_engine, inspect, select, Table, MetaData
from typing import List
import pandas as pd
import datetime
import numpy as np
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['TRANSFORMERS_CACHE'] = 'cache'
from tabulate import tabulate

# %%
username = os.environ["username"]
password = os.environ["password"]
hostname = os.environ["hostname"]
port = os.environ["port"]

# %%
credentials = f"postgresql://{username}:{password}@{hostname}:{port}/aact"
engine = create_engine(credentials)

# create metadata object and reflect all tables
metadata = MetaData()
metadata.reflect(bind=engine)

sql_command = \
"""
SELECT
    studies.nct_id,
    MAX(studies.brief_title) AS brief_title,
    MAX(studies.official_title) AS official_title,
    STRING_AGG(DISTINCT brief_summaries.description, ' ') AS brief_summaries,
    STRING_AGG(DISTINCT detailed_descriptions.description, ' ') AS detailed_descriptions,
    MAX(eligibilities.criteria) AS criteria, 
    MAX(eligibilities.gender) AS gender, 
    MAX(eligibilities.minimum_age) AS minimum_age, 
    MAX(eligibilities.maximum_age) AS maximum_age, 
    MAX(facilities.name) AS facilities, 
    MAX(facilities.city) AS city, 
    MAX(facilities.state) AS state, 
    MAX(facilities.zip) AS zip, 
    MAX(facilities.country) AS country, 
    MAX(studies.study_type) AS study_type
FROM 
    ctgov.studies
INNER JOIN ctgov.brief_summaries ON brief_summaries.nct_id = studies.nct_id 
INNER JOIN ctgov.detailed_descriptions ON detailed_descriptions.nct_id = studies.nct_id 
INNER JOIN ctgov.eligibilities ON eligibilities.nct_id = studies.nct_id 
INNER JOIN ctgov.facilities ON facilities.nct_id = studies.nct_id 
GROUP BY studies.nct_id
ORDER BY studies.nct_id ASC;
"""

assert sql_command is not None
df = pd.read_sql_query(
    sql=sql_command,
    con=engine,
    # params={
    #    # "prompt": f"%{self.prompt}%",
    # }  # type: ignore
)

# Set 'NCTId' as index and remove the 'NCTId' column
df.set_index(df['nct_id'], inplace=True)
df.drop(columns=['nct_id'], inplace=True)

# Convert lists to appropriate data types
for column in df.columns:
    # Remove double quotes from the DataFrame
    df[column] = df[column].apply(lambda x: x.replace('"', '') if isinstance(x, str) else x)
    df[column] = pd.to_datetime(df[column], errors='coerce') if 'date' in column else df[column]

# Close the connection
engine.dispose()

df.to_csv("ctgov.csv")
df
# Out:
#                                                    brief_title  \
# nct_id
# NCT00000102  Congenital Adrenal Hyperplasia: Calcium Channe...
# NCT00000105  Vaccination With Tetanus and KLH to Assess Imm...
# NCT00000113      Correction of Myopia Evaluation Trial (COMET)
# NCT00000116  Randomized Trial of DHA for Retinitis Pigmento...
# NCT00000117  Intravenous Immunoglobulin Therapy in Optic Ne...
# ...                                                        ...
# NCT05808725  Amlodipine Freeze-Dried Powder for Oral Soluti...
# NCT05808751     Clinical Cardiac Rehabilitation Registry Study
# NCT05808777  Validation of the ICH Score for the Prediction...
# NCT05808790  Colorectal Pulmonary Metastases: Pulmonary Met...
# NCT05808829  The Effect of Progressive Relaxation Exercises...
#
#                                                 official_title  \
# nct_id
# NCT00000102                                               None
# NCT00000105  Vaccination With Tetanus Toxoid and Keyhole Li...
# NCT00000113      Correction of Myopia Evaluation Trial (COMET)
# NCT00000116  Clinical Trial of Docosahexaenoic Acid (DHA) i...
# NCT00000117                                               None
# ...                                                        ...
# NCT05808725  Relative Bioavailability Study of Amlodipine P...
# NCT05808751     Clinical Cardiac Rehabilitation Registry Study
# NCT05808777  Validation of the ICH Score for the Prediction...
# NCT05808790  Colorectal Pulmonary Metastases: Pulmonary Met...
# NCT05808829  The Effect of Progressive Muscle Relaxation Ex...
#
#                                                brief_summaries  \
# nct_id
# NCT00000102  This study will test the ability of extended r...
# NCT00000105  The purpose of this study is to learn how the ...
# NCT00000113  To evaluate whether progressive addition lense...
# NCT00000116  The purpose of this trial is to determine whet...
# NCT00000117  To determine whether high-dose intravenous imm...
# ...                                                        ...
# NCT05808725  The goal of this clinical study is to assess t...
# NCT05808751  Establish an electronic cardiac rehabilitation...
# NCT05808777  The goal of this observational study is to ana...
# NCT05808790  COPPER is an international, multicenter, paral...
# NCT05808829  The aim of this randomized controlled study is...
#
#                                          detailed_descriptions  \
# nct_id
# NCT00000102  This protocol is designed to assess both acute...
# NCT00000105  Patients will receive each vaccine once only c...
# NCT00000113  Myopia (nearsightedness) is an important publi...
# NCT00000116  Retinitis pigmentosa (RP) is a group of inheri...
# NCT00000117  Optic neuritis is the leading cause of transie...
# ...                                                        ...
# NCT05808725  A total of 24 healthy, adult, male and female ...
# NCT05808751  Establish an electronic cardiac rehabilitation...
# NCT05808777  The ICH Score had been utilized to predict the...
# NCT05808790  The study is formally endorsed by the Dutch So...
# NCT05808829  The aim of this randomized controlled parallel...
#
#                                                       criteria gender  \
# nct_id
# NCT00000102  Inclusion Criteria:\n\ndiagnosed with Congenit...    All
# NCT00000105  Inclusion Criteria:\n\nPatients must have a di...    All
# NCT00000113  Children between the ages of 6 and 12 years wi...    All
# NCT00000116  Inclusion Criteria:\n\nOcular Criteria:\n\nRet...    All
# NCT00000117  To be eligible, patients must have a history o...    All
# ...                                                        ...    ...
# NCT05808725              Inclusion Criteria:\n\nAdult, Healthy    All
# NCT05808751  Inclusion Criteria:\n\n18 years of age and old...    All
# NCT05808777  Inclusion Criteria:\n\nAged 20 years or older\...    All
# NCT05808790  Inclusion Criteria:\n\nAge ≥ 18 years\nEastern...    All
# NCT05808829  Inclusion Criteria:\n\nVolunteering to partici...    All
#
#             minimum_age maximum_age  \
# nct_id
# NCT00000102    14 Years    35 Years
# NCT00000105    18 Years         N/A
# NCT00000113     6 Years    12 Years
# NCT00000116    18 Years    55 Years
# NCT00000117         N/A    50 Years
# ...                 ...         ...
# NCT05808725    18 Years         N/A
# NCT05808751    18 Years         N/A
# NCT05808777    20 Years         N/A
# NCT05808790    18 Years         N/A
# NCT05808829    18 Years         N/A
#
#                                                     facilities          city  \
# nct_id
# NCT00000102               Medical University of South Carolina    Charleston
# NCT00000105  Division of Hematology, Oncology, and Transpla...   Minneapolis
# NCT00000113        University of Houston, College of Optometry  Philadelphia
# NCT00000116  Berman-Gund Laboratory for the Study of Retina...        Boston
# NCT00000117               Mayo Clinic, Department of Neurology     Rochester
# ...                                                        ...           ...
# NCT05808725       Accutest Research Laboratories (I) Pvt. Ltd.      Vadodara
# NCT05808751  Fuwai Hospital, National Center for Cardiovasc...       Beijing
# NCT05808777                National Taiwan University Hospital        Taipei
# NCT05808790         Amsterdam University Medical Center (AUMC)     Amsterdam
# NCT05808829                                    Gazi University        Ankara
#
#                       state         zip        country  \
# nct_id
# NCT00000102  South Carolina        None  United States
# NCT00000105       Minnesota       55455  United States
# NCT00000113           Texas  77204-6052  United States
# NCT00000116   Massachusetts       02114  United States
# NCT00000117       Minnesota        None  United States
# ...                     ...         ...            ...
# NCT05808725         Gujarat      390016          India
# NCT05808751            None        None          China
# NCT05808777            None         100         Taiwan
# NCT05808790            None     1081 HZ    Netherlands
# NCT05808829  Çankaya/Ankara       06490         Turkey
#
#                                    study_type
# nct_id
# NCT00000102                    Interventional
# NCT00000105                     Observational
# NCT00000113                    Interventional
# NCT00000116                    Interventional
# NCT00000117                    Interventional
# ...                                       ...
# NCT05808725                    Interventional
# NCT05808751  Observational [Patient Registry]
# NCT05808777                     Observational
# NCT05808790                    Interventional
# NCT05808829                    Interventional
#
# [270458 rows x 14 columns]

# %%
credentials = f"postgresql://{username}:{password}@{hostname}:{port}/mimiciii"
engine = create_engine(credentials)

# create metadata object and reflect all tables
metadata = MetaData()
metadata.reflect(bind=engine)

sql_command = \
"""
SELECT
    noteevents.subject_id,
    MAX(noteevents.hadm_id) AS hadm_id,
    MAX(noteevents.category) AS category,
    MAX(noteevents.description) AS description,
    STRING_AGG(DISTINCT noteevents.text, ' ') AS text
FROM 
    mimic.noteevents
GROUP BY noteevents.subject_id
ORDER BY noteevents.subject_id ASC
"""

assert sql_command is not None
df = pd.read_sql_query(
    sql=sql_command,
    con=engine,
)

# Set 'NCTId' as index and remove the 'NCTId' column
df.set_index(df['subject_id'], inplace=True)
df.drop(columns=['subject_id'], inplace=True)

# Convert lists to appropriate data types
for column in df.columns:
    # Remove double quotes from the DataFrame
    df[column] = df[column].apply(lambda x: x.replace(
        '"', '') if isinstance(x, str) else x)
    df[column] = pd.to_datetime(
        df[column], errors='coerce') if 'date' in column else df[column]

# Close the connection
engine.dispose()

df.to_csv("mimiciii.csv")
df
# Out:
#              hadm_id        category                     description  \
# subject_id
# 2           163353.0   Nursing/other                          Report
# 3           145834.0       Radiology     VIDEO OROPHARYNGEAL SWALLOW
# 4           185777.0       Radiology      US ABD LIMIT, SINGLE ORGAN
# 5           178980.0   Nursing/other                          Report
# 6           107064.0       Radiology  R UNILAT LOWER EXT VEINS RIGHT
# ...              ...             ...                             ...
# 99985       176670.0     Social Work       Social Work Progress Note
# 99991       151118.0  Rehab Services                          Report
# 99992       197084.0       Radiology  R UNILAT UP EXT VEINS US RIGHT
# 99995       137810.0       Radiology                          Report
# 99999       113369.0      Physician                           Report
#
#                                                          text
# subject_id
# 2           Neonatology Attending Triage Note\n\nBaby [**N...
# 3           \n\n\n [**2101-10-11**] 9:06 PM\n CHEST (PRE-O...
# 4           [**2187**]: Pt c/o cough, non-productive, dry....
# 5           NICU Nursing Septic Workup Note\n[**Name8 (MD)...
# 6           [**2175-5-25**] 10:52 AM\n CHEST (PRE-OP PA & ...
# ...                                                       ...
# 99985       53 yo male pt with h/o ? PNA transffered from ...
# 99991       [**2184-12-27**] 11:35 AM\n CHEST (PA & LAT)  ...
# 99992       [**2144-7-10**] 8:04 AM\n CHEST PORT. LINE PLA...
# 99995       [**2147-1-10**] 8:15 AM\n CAROTID SERIES COMPL...
# 99999       63 yo f POD1 PLIF L4-5 experienced episode of ...
#
# [46146 rows x 4 columns]
